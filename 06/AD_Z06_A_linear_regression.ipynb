# %% [markdown]
# # Regresja liniowa i wielomianowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k');
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
x=np.vstack(x)
model1 = linear_model.LinearRegression()
model1.fit(x, y)
# Out:
# LinearRegression()

# %%
print(model1.coef_)
print(model1.intercept_)
print(model1.score(x,y))
# Out:
# [5.61270786]
# -2.3256046637586163
# 0.48936533467172727

# %%
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
plt.plot(x, model1.predict(x), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie 1
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
model2 = make_pipeline(PolynomialFeatures(2), linear_model.LinearRegression())
model2.fit(x, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model2.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie 2
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model3 = make_pipeline(PolynomialFeatures(7), linear_model.LinearRegression())
model3.fit(x, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=7)),
#                 ('linearregression', LinearRegression())])

# %%
# Plot outputs
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.scatter(x, y,  color='black')
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model3.predict(x_plot), color='blue',linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie 3
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model4 = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())
model4.fit(x, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=4)),
#                 ('linearregression', LinearRegression())])

# %%
# Plot outputs
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.scatter(x, y, color="black")
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model4.predict(x_plot), color="blue", linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie 4
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
model5 = make_pipeline(PolynomialFeatures(4), linear_model.LinearRegression())
model5.fit(x, y)
# Plot outputs
plt.figure(figsize=(6, 6))
axes = plt.gca()
axes.set_xlim([0, 3])
axes.set_ylim([0, 8])
plt.scatter(x, y, color="black")
x_plot = np.vstack(np.linspace(0, 10, 100))
plt.plot(x_plot, model5.predict(x_plot), color="blue", linewidth=3)
plt.show()

# %% [markdown]
# # Zadanie 5
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_plot, model1.predict(x_plot), 'r');
plt.plot(x_plot, model2.predict(x_plot), 'g');
plt.plot(x_plot, model3.predict(x_plot), 'b');
plt.plot(x_plot, model4.predict(x_plot), 'g');
plt.plot(x_plot, model5.predict(x_plot), 'r');
plt.plot(x, y, 'ok', ms=4);
plt.show()

# %% [markdown]
# # Zadanie 6
# Musimy mieć jakąś miarę oceny.

# %%
from sklearn import  metrics

model = model1

error = np.average( np.abs(model.predict(x) -y) )
print("Mean absolute errors: {}".format(error))
print("Mean absolute errors: {}".format(metrics.mean_absolute_error(y, model.predict(x))))

error = np.average( (model.predict(x) -y) **2 )
print("Mean squared error: {}".format(error))
print("Mean squared error: {}".format( metrics.mean_squared_error(y, model.predict(x)) ))

error = np.median( np.abs(model.predict(x) -y) )
print("Median absolute error: {}".format( error ))
print("Median absolute error: {}".format( metrics.median_absolute_error(y, model.predict(x)) ))

print("R^2: {}".format(metrics.r2_score(y, model.predict(x))))
ss_res=np.sum( (y-model.predict(x))**2 )
ss_tot=np.sum( (y-np.mean(y))**2 )
R=1-ss_res/ss_tot
print("R^2: {}".format(R))

error = 1-np.var(y - model.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error ))
print("Explained variance score: {}".format( metrics.explained_variance_score(y, model.predict(x)) ))

error1 = error
# Out:
# Mean absolute errors: 3.4823440950590276
# Mean absolute errors: 3.4823440950590276
# Mean squared error: 22.184218003265354
# Mean squared error: 22.184218003265354
# Median absolute error: 2.3988633089775475
# Median absolute error: 2.3988633089775475
# R^2: 0.48936533467172727
# R^2: 0.48936533467172727
# Explained variance score: 0.48936533467172705
# Explained variance score: 0.48936533467172705

# %% [markdown]
# # Zadanie 7
#
# Wylicz powyższe miary dla wszytkich modeli.

# %%
model = model2

error = np.average( np.abs(model.predict(x) -y) )
print("Mean absolute errors: {}".format(error))
print("Mean absolute errors: {}".format(metrics.mean_absolute_error(y, model.predict(x))))

error = np.average( (model.predict(x) -y) **2 )
print("Mean squared error: {}".format(error))
print("Mean squared error: {}".format( metrics.mean_squared_error(y, model.predict(x)) ))

error = np.median( np.abs(model.predict(x) -y) )
print("Median absolute error: {}".format( error ))
print("Median absolute error: {}".format( metrics.median_absolute_error(y, model.predict(x)) ))

print("R^2: {}".format(metrics.r2_score(y, model.predict(x))))
ss_res=np.sum( (y-model.predict(x))**2 )
ss_tot=np.sum( (y-np.mean(y))**2 )
R=1-ss_res/ss_tot
print("R^2: {}".format(R))

error = 1-np.var(y - model.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error ))
print("Explained variance score: {}".format( metrics.explained_variance_score(y, model.predict(x)) ))

error2 = error
# Out:
# Mean absolute errors: 2.738884038732323
# Mean absolute errors: 2.738884038732323
# Mean squared error: 10.700404623263921
# Mean squared error: 10.700404623263921
# Median absolute error: 2.8301415376606727
# Median absolute error: 2.8301415376606727
# R^2: 0.7536988893242388
# R^2: 0.7536988893242388
# Explained variance score: 0.7536988893242388
# Explained variance score: 0.7536988893242388

# %%
model = model3

error = np.average( np.abs(model.predict(x) -y) )
print("Mean absolute errors: {}".format(error))
print("Mean absolute errors: {}".format(metrics.mean_absolute_error(y, model.predict(x))))

error = np.average( (model.predict(x) -y) **2 )
print("Mean squared error: {}".format(error))
print("Mean squared error: {}".format( metrics.mean_squared_error(y, model.predict(x)) ))

error = np.median( np.abs(model.predict(x) -y) )
print("Median absolute error: {}".format( error ))
print("Median absolute error: {}".format( metrics.median_absolute_error(y, model.predict(x)) ))

print("R^2: {}".format(metrics.r2_score(y, model.predict(x))))
ss_res=np.sum( (y-model.predict(x))**2 )
ss_tot=np.sum( (y-np.mean(y))**2 )
R=1-ss_res/ss_tot
print("R^2: {}".format(R))

error = 1-np.var(y - model.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error ))
print("Explained variance score: {}".format( metrics.explained_variance_score(y, model.predict(x)) ))

error3 = error
# Out:
# Mean absolute errors: 0.14340446292368203
# Mean absolute errors: 0.14340446292368203
# Mean squared error: 0.032439710897015875
# Mean squared error: 0.032439710897015875
# Median absolute error: 0.12199492792020816
# Median absolute error: 0.12199492792020816
# R^2: 0.9992533051688004
# R^2: 0.9992533051688004
# Explained variance score: 0.9992533051688004
# Explained variance score: 0.9992533051688004

# %%
model = model4

error = np.average( np.abs(model.predict(x) -y) )
print("Mean absolute errors: {}".format(error))
print("Mean absolute errors: {}".format(metrics.mean_absolute_error(y, model.predict(x))))

error = np.average( (model.predict(x) -y) **2 )
print("Mean squared error: {}".format(error))
print("Mean squared error: {}".format( metrics.mean_squared_error(y, model.predict(x)) ))

error = np.median( np.abs(model.predict(x) -y) )
print("Median absolute error: {}".format( error ))
print("Median absolute error: {}".format( metrics.median_absolute_error(y, model.predict(x)) ))

print("R^2: {}".format(metrics.r2_score(y, model.predict(x))))
ss_res=np.sum( (y-model.predict(x))**2 )
ss_tot=np.sum( (y-np.mean(y))**2 )
R=1-ss_res/ss_tot
print("R^2: {}".format(R))

error = 1-np.var(y - model.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error ))
print("Explained variance score: {}".format( metrics.explained_variance_score(y, model.predict(x)) ))

error4 = error
# Out:
# Mean absolute errors: 0.14380915361628632
# Mean absolute errors: 0.14380915361628632
# Mean squared error: 0.032772556971299785
# Mean squared error: 0.032772556971299785
# Median absolute error: 0.1348100610558567
# Median absolute error: 0.1348100610558567
# R^2: 0.9992456437428388
# R^2: 0.9992456437428388
# Explained variance score: 0.9992456437428388
# Explained variance score: 0.9992456437428388

# %%
model = model5

error = np.average( np.abs(model.predict(x) -y) )
print("Mean absolute errors: {}".format(error))
print("Mean absolute errors: {}".format(metrics.mean_absolute_error(y, model.predict(x))))

error = np.average( (model.predict(x) -y) **2 )
print("Mean squared error: {}".format(error))
print("Mean squared error: {}".format( metrics.mean_squared_error(y, model.predict(x)) ))

error = np.median( np.abs(model.predict(x) -y) )
print("Median absolute error: {}".format( error ))
print("Median absolute error: {}".format( metrics.median_absolute_error(y, model.predict(x)) ))

print("R^2: {}".format(metrics.r2_score(y, model.predict(x))))
ss_res=np.sum( (y-model.predict(x))**2 )
ss_tot=np.sum( (y-np.mean(y))**2 )
R=1-ss_res/ss_tot
print("R^2: {}".format(R))

error = 1-np.var(y - model.predict(x) )/np.var(y)
print("Explained variance score: {}".format( error ))
print("Explained variance score: {}".format( metrics.explained_variance_score(y, model.predict(x)) ))

error5 = error
# Out:
# Mean absolute errors: 0.14380915361628632
# Mean absolute errors: 0.14380915361628632
# Mean squared error: 0.032772556971299785
# Mean squared error: 0.032772556971299785
# Median absolute error: 0.1348100610558567
# Median absolute error: 0.1348100610558567
# R^2: 0.9992456437428388
# R^2: 0.9992456437428388
# Explained variance score: 0.9992456437428388
# Explained variance score: 0.9992456437428388
